# %%
import os 
import random
import shutil
from PIL import Image

# %%
# for ImageNet-V2, transform given wordnet-id to number 

with open('/home/stud/afroehli/datasets/imagenet_v2_label_transform/imagenet_1k_label_order.txt', 'r') as imagenet_v2_label_order_file:
    inet_v2_label_order = imagenet_v2_label_order_file.readlines()

# %%
# define dataset, and wnid 
# define number of images to be stored 
class_a = 'n07714571'
class_b_l1 = 'n04286575'
class_b_c1 = 'n03991062'
class_b_c2 = 'n02206856'
class_b_c3 = 'n07715103'
class_r = 'n02100877'

# select images randomly and store them at a separate place
# img_str_info = [(class_a, 'class_a_inet_1k', '/home/stud/afroehli/datasets/ImageNet1k/imagenet1k/ILSVRC/Data/CLS-LOC/val_sorted'),
# (class_a, 'class_a_inet_c', '/home/stud/afroehli/datasets/ImagenetC/gaussian_blur/3'), (class_a, 'class_a_inet_r', '/home/stud/afroehli/datasets/ImagenetR_orig/imagenet-r'),
# (class_a, 'class_a_inet_v2', '/home/stud/afroehli/datasets/ImagenetV2/imagenetv2-threshold0.7-format-val')]

img_str_info = [(class_r, 'class_r_inet_1k', '/home/stud/afroehli/datasets/ImageNet1k/imagenet1k/ILSVRC/Data/CLS-LOC/val_sorted')]

# (class_b_c1, 'class_b_c1_inet_1k', '/home/stud/afroehli/datasets/ImageNet1k/imagenet1k/ILSVRC/Data/CLS-LOC/val_sorted'), (class_b_c2, 'class_b_c2_inet_1k', '/home/stud/afroehli/datasets/ImageNet1k/imagenet1k/ILSVRC/Data/CLS-LOC/val_sorted'),
# (class_b_c3, 'class_b_c3_inet_1k', '/home/stud/afroehli/datasets/ImageNet1k/imagenet1k/ILSVRC/Data/CLS-LOC/val_sorted'), (class_r, 'class_r_inet_1k', '/home/stud/afroehli/datasets/ImageNet1k/imagenet1k/ILSVRC/Data/CLS-LOC/val_sorted')]

random.seed(9)

for wnid, store_name, dset_path in img_str_info: 
    if store_name == 'class_a_inet_v2':
        wnid = inet_v2_label_order.index(wnid +'\n')
        wnid = str(wnid)

    all_imgs_paths = os.listdir(dset_path + '/' + wnid)

    for i in range(3):
        img_index = random.randint(0, len(all_imgs_paths) - 1)
        next_img_path = dset_path + '/' + wnid + '/' + all_imgs_paths[img_index]
        im = Image.open(next_img_path)
        im_w, im_h = im.size
        new_w = 300
        im.resize((200, 200), resample = Image.BICUBIC)
        im.save('/home/stud/afroehli/coding/dinov2_ood/example_pics/' + f'{store_name}_{i}.png')
        #shutil.copyfile(next_img_path, '/home/stud/afroehli/coding/dinov2_ood/example_pics/' + f'{store_name}_{i}.png')
